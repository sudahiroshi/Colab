# %% [markdown]
# ## ハッシュ化の方法
# パスワードのハッシュ化を行うときパスワードと一緒に「salt」と呼ばれるランダムの値を合わせてからハッシュ化しそれを保存する
#
# 今回は「salt」を固定してハッシュ化に使う
#
# - [Open with Colab](https://colab.research.google.com/github/uemotota/Colab/blob/master/hash.ipynb)

# %% [markdown]
# ###パスワードのハッシュ化
# ？と？を合わせてハッシュ化して求められたハッシュ値「hash」だけを保存するのではなく,
# 「"6&"+salt+"&"+hash」のように,パスワードと一緒にハッシュ化したsaltも保存する
#
# 事前学習などを元に（？+？）の「？」の部分を正しい変数に変更して動作してください

# %%
import hashlib
password = "hogehoge"
salt = "salt"
hash = hashlib.sha256((？+？).encode()).hexdigest()
print( hash )
print( "6&" + salt + "&" + hash )
# Out:
# 2b5c17296ff0f658c0945ec89b4ed98e9265dfa72887da5bf27332af619693f9
# 6&tekitounamojiretsu&2b5c17296ff0f658c0945ec89b4ed98e9265dfa72887da5bf27332af619693f9
