# %% [markdown]
# ## このファイルの使い方
# 上から順にやってlistの使い方を覚える
#
# - [Open in colaboratory](https://colab.research.google.com/github.com/uemotota/Colab/blob/master/hash.ipynb)

# %% [markdown]
# パスワードのハッシュ化

# %%
import hashlib
password = "hogehoge"
salt = "salt"
hash = hashlib.sha256((password+salt).encode()).hexdigest()
print( hash )
print( "6&" + salt + "&" + hash )
# Out:
# 2b5c17296ff0f658c0945ec89b4ed98e9265dfa72887da5bf27332af619693f9
# 6&tekitounamojiretsu&2b5c17296ff0f658c0945ec89b4ed98e9265dfa72887da5bf27332af619693f9
